# %% [markdown]
# ## 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
# ## Hint: 服飾

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img=cv2.imread('1587990589952.jpg')
plt.imshow(img)

# %%
print('資料來源:google scholar與各篇paper的Keyword')
print('目標:讓讀者可以快速了解paper涵蓋的內容')
print('評估指標:常以模型、使用變數...等語所使用的工具與資料相關')
# Out:
# 資料來源:google scholar與各篇paper的Keyword
# 目標:讓讀者可以快速了解paper涵蓋的內容
# 評估指標:常以模型、使用變數...等語所使用的工具與資料相關
